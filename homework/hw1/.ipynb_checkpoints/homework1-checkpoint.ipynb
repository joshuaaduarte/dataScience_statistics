# %% [markdown]
# ## Homework One
# ### Completed By: Joshua Duarte

# %% [markdown]
# # Problem 1 (15 points)
# Find whether the following are valid PDFs. Note: You may do the proofs by hand, or you may use a symbolic calculator / code. If you use a computer or calculator, please include a screenshot of the code. Also, plots of the function over the sample space can be used to show positivity.
# (a) p(x) = 1/2 cos(x) , Ω = [−π/2,π/2]
# (b) p(x) = 1/(1 + e−x) , Ω = R
# (c) p(x) = 1/3 x^3 , Ω = [0,1]
# (d) p(x) = 1/x , Ω = N (the natural numbers {1,2,3,...})
# (e) p(x) = 2^(−x) , Ω = N

# %% [markdown]
# ## 1a) p(x) 1/2 cos(x),  Ω = [−π/2,π/2]

# %%
from scipy.integrate import quad
import numpy as np 

def funcA(x): 
    return 1/2 * np.cos(x)

result, error = quad(funcA, -1* np.pi/2,np.pi/2)
                     
print(result)
print(error)
# Out:
# 1.0
# 1.1102230246251565e-14

# %%
import matplotlib.pyplot as plt
import numpy as np 
x = np.linspace(-np.pi/2, np.pi/2, num = 100)
p = 1/2 * np.cos(x)

plt.plot(x,p)
plt.xlabel('x')
plt.ylabel('p(x)')
plt.title('Plot of p(x) = 1/2 * cos(x)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 1b) p(x) = 1/(1 + e−x) , Ω = R

# %%
from scipy.integrate import quad
import numpy as np 

def funcA(x): 
    return 1/(1+np.exp(-x))

result, error = quad(funcA, -10,10)
                     
print(result)
print(error)
# Out:
# 9.999999999999998
# 1.1102230246251563e-13

# %%
import matplotlib.pyplot as plt
import numpy as np 
x = np.linspace(-10, 10, num = 100)
p = 1/(1+np.exp(-x))

plt.plot(x,p)
plt.xlabel('x')
plt.ylabel('p(x)')
plt.title('Plot of p(x) = 1/(1+exp(-x))')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 1c) p(x) = 1/3 x^3 , Ω = [0,1]

# %%
from scipy.integrate import quad
import numpy as np 

def funcC(x): 
    return 1/3 * (x**3)

result, error = quad(funcC, 0,1)
                     
print(result)
print(error)
# Out:
# 0.08333333333333333
# 9.25185853854297e-16

# %%
import matplotlib.pyplot as plt
import numpy as np 
x = np.linspace(0, 1, num = 100)
p = 1/3 * (x**3)

plt.plot(x,p)
plt.xlabel('x')
plt.ylabel('p(x)')
plt.title('Plot of p(x) = 1/3 * (x**3))')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 1d) p(x) = 1/x , Ω = N (the natural numbers {1,2,3,...})

# %%
from scipy.integrate import quad
import numpy as np 

x = np.linspace(1,10000,10000)

funcE = 1/x

result = np.sum(funcE)
                     
print(result)
# Out:
# 9.787606036044384

# %%
import matplotlib.pyplot as plt
import numpy as np 
x = np.linspace(1, 1000, num = 1000)
p = 1/x

plt.plot(x,p)
plt.xlabel('x')
plt.ylabel('p(x)')
plt.title('Plot of p(x) = 1/x)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 1e) p(x) = 2^(−x) , Ω = N

# %%
from scipy.integrate import quad
import numpy as np 

x = np.linspace(1,10000,10000)

funcE =  2**(-x)

result = np.sum(funcE)
                     
print(result)
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
import numpy as np 
x = np.linspace(1, 1000, num = 1000)
p = 2**(-x)

plt.plot(x,p)
plt.xlabel('x')
plt.ylabel('p(x)')
plt.title('Plot of p(x) = 2**(-x)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Problem 2 (4+4+4+1 points)
# Consider the function f : R2 →R,
# f(x1,x2) = x31/3 −4x1 + x32/3 − 16x2
# (a) Find the set of stationary points of f.
# (b) Determine which of these stationary points are local maxima and local minima.
# (c) Plot the function using one of Matplotlib’s surface plotters (plot surface, plot wireframe, or plot trisurf). Indicate in the plot the stationary points and extrema of the function.
# (d) What is the solution of the problem: maximize f(x1,x2) over R2?

# %% [markdown]
# ## A

# %%
import numpy as np
import sympy as sp
from scipy.optimize import fsolve

x1, x2 = sp.symbols('x1 x2')
f = (x1**3)/3 - (4* x1) + (x2**3)/3 - (16*x2)


f_x1 = sp.diff(f, x1)
f_x2 = sp.diff(f, x2)

# %% [markdown]
# The sets of stationary points of the function are below as they are found where the derivative of the function provided equals 0:
#
# + (-2,-4)
# + (-2,4)
# + (2,-4)
# + (2,4)

# %% [markdown]
# ## B

# %% [markdown]
# By inspecting the plot of the function below, it can be seen that (-2,-4) is a local maxima, (-2,4) is a local maxima, (2,-4) is a local minima, and (2,4) is a local minima

# %% [markdown]
# ## C

# %%
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
import numpy as np 

x1 = np.linspace(-5,5,100)
x2 = np.linspace(-5,5,100)

x1,x2 = np.meshgrid(x1,x2)

f = (x1**3)/3 - (4* x1) + (x2**3)/3 - (16*x2)

fig= plt.figure()

ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x1,x2,f, cmap='coolwarm')

ax.set_xlabel('X1 axis')
ax.set_ylabel('X2 axis')
ax.set_zlabel('f axis')


ax.view_init(15,155)

plt.show()

# %% [markdown]
# ## D
#
# There is no solution to maximizing the function over all real numbers as there is no maximum as the function is constantly increasing.

# %% [markdown]
# # Problem 3 (2+2+3+3 points)
# A study of washing machines found their lifetime T to follow an exponential distribution:
# pT (t) = 0.1e−0.1t
# with t measured in years.
# (a) What is the mean lifetime of washing machines?
# (b) What is the standard deviation?
# (c) What percentage of washing machine are expected to fail in 10 years?
# (d) What is the median life of washing machines?

# %%
result, error = quad(funcpT, 0,100)
                     
print(result)
print(error)
# Out:
# 0.9999546000702377
# 2.8328449670573503e-14

# %%
mean = result/100
print('The mean lifetime of washing machines is ', mean, 'years.')
# Out:
# The mean lifetime of washing machines is  0.009999546000702377 years.

# %%
from scipy.integrate import quad
import statistics as stats
from scipy.optimize import bisect


def funcptOriginal(t):
    return 0.1*np.exp(-0.1*t)

def funcptMean(t):
    return t*0.1*np.exp(-0.1*t)

def funcptVariance(t):
    return (t**2)*0.1*np.exp(-0.1*t)

def funcCDF(t, median):
    return quad(funcptOriginal, 0, t)[0] - 0.5



years = np.arange(0,1000)
lifetime = funcptOriginal(years)

mean, error = quad(funcptMean, 0,1000)
variance, error = quad(funcptVariance, 0,1000)
variance -= mean**2
standard_deviation = np.sqrt(variance)
median = bisect(funcCDF, 0, 1000, args=(median,))


print('The mean lifetime of washing machines is ', mean, 'years.')
print('The standard deviation of the lifetime of washing machines is ', standard_deviation, 'years.')

failure, error = quad(funcptOriginal, 0,10)
                     
print('The percentage of washing machines expected to fail in 10 years is ', failure*100, 'percent')
print('The median life of washing machines is', median, 'years')
# Out:
# The mean lifetime of washing machines is  10.000000000000004 years.
# The standard deviation of the lifetime of washing machines is  9.999999999999996 years.
# The percentage of washing machines expected to fail in 10 years is  63.21205588285578 percent
# The median life of washing machines is 6.931471805598832 years

# %%
from scipy.integrate import quad

def funcptOriginal(t):
    return 0.1*np.exp(-0.1*t)

def funcptMean(t):
    return t*0.1*np.exp(-0.1*t)

def funcptVariance(t):
    return (t**2)*0.1*np.exp(-0.1*t)

mean, error = quad(funcptMean, 0, 1000)
variance, error = quad(funcptVariance, 0, 1000)
variance -= mean**2

print("Mean:", mean)
print("Variance:", variance)
# Out:
# Mean: 10.000000000000004
# Variance: 99.99999999999993

# %%
from scipy.integrate import quad
import numpy as np 

def funcC(t): 
    return (t*0.1*np.exp(-0.1*t))

result, error = quad(funcC, 0,1000000)
                     
print(result)
print(error)
# Out:
# 2.2381388036409817e-42
# 4.450103382238331e-42

# %%
import matplotlib.pyplot as plt
import numpy as np 
T = np.linspace(0, 100, num = 100)
p = 0.1*np.exp(-0.1*T)

plt.plot(T,p)
plt.xlabel('T')
plt.ylabel('p(T)')
plt.title('Plot of p(T) = 0.1*np.exp(-0.1*t)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Problem 4 (2+3+3 points)
# Measurements are made of the length L and width W of a rectangular component. As-
# sume that L ∼ U(9.95,10.05) and W ∼ U(4.9,5.1), and that they are independent random
# variables.
# (a) Find P(L < 9.98)
# (b) Draw the region in the LW plane corresponding to the event (L∈[9.96,9.98] ∩ W ∈[5.0,5.05]) and compute its probability.
# (c) Draw the region in the LW plane corresponding to the event (L∈[9.96,9.98] ∪ W ∈[5.0,5.05]) and compute its probability.

# %% [markdown]
# ### Problem 5 (3 points)
# Certain pipes are specified to have a roughness coefficient of between 0.2 and 0.3. The manufacturing process is known produce pipes with normally distributed roughnesses with mean 0.25 and a standard deviation of 0.03. What percentage of pipes is expected to meet the specification?
# Hint: stats.norm

# %%
mean = 0.25
standard_dev = 0.03


from scipy.integrate import quad
import numpy as np 

def func5(y): 
    return (1/np.sqrt(2*np.pi*(0.03**2))) * np.exp((-1/2)*(((y-.25)**2)/(0.03**2)))

result, error = quad(func5, .2,.3)
                     
print(result)
print(error)
# Out:
# 0.9044192954543705
# 1.0753072482249986e-13

# %%
import scipy.stats as stats
import numpy as np

mean = 0.25
standard_deviation = 0.03
x = np.linspace(.2,.3,100)

pdf = stats.norm( mean, standard_deviation)

prob = pdf.cdf(.3) - pdf.cdf(.2)

print(prob)
# Out:
# 0.9044192954543706
